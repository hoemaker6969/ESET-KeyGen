# %% [markdown]
# # VibeVoice Colab
# ### 🏷️ **Credits & License**
#
# * 🔗 [VibeVoice GitHub Repository](https://github.com/microsoft/VibeVoice)
# * 🤗 [VibeVoice on Hugging Face](https://huggingface.co/microsoft/VibeVoice-1.5B)
# * 📄 **License**: Provided under the [MIT License](https://github.com/microsoft/VibeVoice/blob/main/LICENSE)
#
# ### ⚠️ **Usage Disclaimer**
#
# This tool enables **AI-generated podcast creation** using cloned voices. While it can be a powerful resource for storytelling, education, and creative projects, it also carries risks if misused. By using this tool, you agree to the following guidelines:
#
# * **No Misrepresentation**: Do not use cloned voices to impersonate real people or mislead listeners into believing AI-generated voices are authentic recordings without disclosure.
# * **Transparency**: Clearly disclose when podcast content has been generated with AI, including synthetic voices or AI-written scripts.
# * **No Harmful Content**: Do not produce or distribute content that promotes hate, harassment, misinformation, defamation, or any form of harmful/deceptive material.
# * **Legal Compliance**: Ensure all use of this tool complies with copyright laws, data protection regulations, and all applicable legal and ethical standards.
# * **Respect for Consent**: Do not replicate or publish anyone’s voice without explicit permission.
#
# > ⚖️ **Legal Responsibility**
#
# > The developers of this tool disclaim all liability for misuse. **Users bear full responsibility** for ensuring that their usage complies with all applicable laws, regulations, and ethical guidelines.

# %%
# @title Install VibeVoice

# %cd /content/


# !git clone https://github.com/microsoft/VibeVoice.git
# Download colab.py
# %cd /content/VibeVoice/demo
# !wget https://raw.githubusercontent.com/NeuralFalconYT/VibeVoice/refs/heads/main/demo/colab.py


# (Optional) If you experience compatibility issues with the latest version, you can use a pinned fork instead:
# !git clone https://github.com/NeuralFalconYT/VibeVoice.git



# %cd /content/VibeVoice/
# !pip install -e .
# !pip install pydub>=0.25.1

from IPython.display import clear_output
clear_output()

# %%
#@title Run Official Gradio UI
# !python /content/VibeVoice/demo/gradio_demo.py --model_path "microsoft/VibeVoice-1.5B" --inference_steps 10 --share

# %%
#@title Automatically save podcast to your Google Drive [Optional]
Enable_Drive_Save= False  # @param {type: "boolean"}
if Enable_Drive_Save:
  from google.colab import drive
  drive.mount('/content/gdrive/')

# %%
#@title Run VibeVoice Podcast
# !python /content/VibeVoice/demo/colab.py --model_path microsoft/VibeVoice-1.5B --inference_steps 10 --debug --share
# Out:
# 2026-01-04 15:41:00.982834: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767541261.000743     739 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767541261.005846     739 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767541261.018810     739 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767541261.018834     739 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767541261.018838     739 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767541261.018844     739 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-04 15:41:01.022815: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:vibevoice.modular.modular_vibevoice_tokenizer:APEX FusedRMSNorm not available, using native implementation
# 📂 Download directory: /content/VibeVoice/VibeVoice-1.5B
# 📦 Found 9 files in repo 'microsoft/VibeVoice-1.5B'. Checking cache ...
# Processing files:   0% 0/9 [00:00<?, ?file/s]
# .gitattributes:   0% 0.00/1.57k [00:00<?, ?B/s]
# .gitattributes: 16.0kB [00:00, 58.7kB/s]
# ⬇️ Downloaded: .gitattributes
# Processing files:  11% 1/9 [00:00<00:04,  1.87file/s]
# README.md:   0% 0.00/7.10k [00:00<?, ?B/s]
# README.md: 16.0kB [00:00, 50.1kB/s]
# ⬇️ Downloaded: README.md
# Processing files:  22% 2/9 [00:01<00:03,  1.76file/s]
# config.json:   0% 0.00/2.70k [00:00<?, ?B/s]
# config.json: 16.0kB [00:00, 61.1kB/s]
# ⬇️ Downloaded: config.json
# Processing files:  33% 3/9 [00:01<00:03,  1.81file/s]
# Fig1.png:   0% 0.00/150k [00:00<?, ?B/s]
# Fig1.png: 160kB [00:00, 606kB/s]
# ⬇️ Downloaded: Fig1.png
# Processing files:  44% 4/9 [00:02<00:02,  1.82file/s]
# model-00001-of-00003.safetensors:   0% 0.00/1.84G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0% 8.00k/1.84G [00:00<17:45:08, 30.9kB/s]
# model-00001-of-00003.safetensors:   2% 29.0M/1.84G [00:00<00:18, 106MB/s]
# model-00001-of-00003.safetensors:   4% 66.0M/1.84G [00:00<00:09, 200MB/s]
# model-00001-of-00003.safetensors:   5% 95.7M/1.84G [00:00<00:07, 236MB/s]
# model-00001-of-00003.safetensors:   7% 123M/1.84G [00:00<00:07, 243MB/s]
# model-00001-of-00003.safetensors:   8% 150M/1.84G [00:00<00:07, 254MB/s]
# model-00001-of-00003.safetensors:  10% 182M/1.84G [00:00<00:06, 279MB/s]
# model-00001-of-00003.safetensors:  11% 211M/1.84G [00:00<00:06, 285MB/s]
# model-00001-of-00003.safetensors:  13% 245M/1.84G [00:01<00:05, 307MB/s]
# model-00001-of-00003.safetensors:  15% 278M/1.84G [00:01<00:05, 318MB/s]
# model-00001-of-00003.safetensors:  17% 313M/1.84G [00:01<00:04, 334MB/s]
# model-00001-of-00003.safetensors:  18% 348M/1.84G [00:01<00:04, 343MB/s]
# model-00001-of-00003.safetensors:  20% 382M/1.84G [00:01<00:04, 349MB/s]
# model-00001-of-00003.safetensors:  22% 416M/1.84G [00:01<00:04, 331MB/s]
# model-00001-of-00003.safetensors:  24% 448M/1.84G [00:02<00:18, 83.0MB/s]
# model-00001-of-00003.safetensors:  25% 471M/1.84G [00:03<00:24, 59.5MB/s]
# model-00001-of-00003.safetensors:  26% 494M/1.84G [00:03<00:19, 73.6MB/s]
# model-00001-of-00003.safetensors:  28% 521M/1.84G [00:03<00:15, 93.8MB/s]
# model-00001-of-00003.safetensors:  29% 549M/1.84G [00:03<00:11, 117MB/s]
# model-00001-of-00003.safetensors:  31% 576M/1.84G [00:03<00:09, 142MB/s]
# model-00001-of-00003.safetensors:  32% 600M/1.84G [00:04<00:08, 156MB/s]
# model-00001-of-00003.safetensors:  33% 623M/1.84G [00:04<00:07, 172MB/s]
# model-00001-of-00003.safetensors:  34% 649M/1.84G [00:04<00:06, 193MB/s]
# model-00001-of-00003.safetensors:  36% 673M/1.84G [00:04<00:06, 202MB/s]
# model-00001-of-00003.safetensors:  37% 697M/1.84G [00:04<00:05, 214MB/s]
# model-00001-of-00003.safetensors:  38% 720M/1.84G [00:04<00:05, 221MB/s]
# model-00001-of-00003.safetensors:  39% 743M/1.84G [00:04<00:05, 220MB/s]
# model-00001-of-00003.safetensors:  41% 766M/1.84G [00:04<00:05, 220MB/s]
# model-00001-of-00003.safetensors:  42% 790M/1.84G [00:04<00:04, 231MB/s]
# model-00001-of-00003.safetensors:  43% 813M/1.84G [00:04<00:04, 231MB/s]
# model-00001-of-00003.safetensors:  44% 836M/1.84G [00:05<00:04, 233MB/s]
# model-00001-of-00003.safetensors:  46% 858M/1.84G [00:05<00:04, 233MB/s]
# model-00001-of-00003.safetensors:  47% 881M/1.84G [00:05<00:04, 229MB/s]
# model-00001-of-00003.safetensors:  48% 903M/1.84G [00:05<00:04, 230MB/s]
# model-00001-of-00003.safetensors:  49% 931M/1.84G [00:05<00:04, 248MB/s]
# model-00001-of-00003.safetensors:  51% 955M/1.84G [00:05<00:03, 250MB/s]
# model-00001-of-00003.safetensors:  52% 979M/1.84G [00:05<00:03, 251MB/s]
# model-00001-of-00003.safetensors:  53% 0.98G/1.84G [00:05<00:03, 243MB/s]
# model-00001-of-00003.safetensors:  55% 1.01G/1.84G [00:05<00:03, 253MB/s]
# model-00001-of-00003.safetensors:  56% 1.03G/1.84G [00:06<00:03, 245MB/s]
# model-00001-of-00003.safetensors:  57% 1.05G/1.84G [00:06<00:03, 240MB/s]
# model-00001-of-00003.safetensors:  58% 1.07G/1.84G [00:06<00:03, 231MB/s]
# model-00001-of-00003.safetensors:  60% 1.10G/1.84G [00:06<00:03, 218MB/s]
# model-00001-of-00003.safetensors:  61% 1.13G/1.84G [00:06<00:03, 244MB/s]
# model-00001-of-00003.safetensors:  63% 1.16G/1.84G [00:06<00:02, 266MB/s]
# model-00001-of-00003.safetensors:  64% 1.18G/1.84G [00:06<00:02, 237MB/s]
# model-00001-of-00003.safetensors:  65% 1.20G/1.84G [00:06<00:02, 237MB/s]
# model-00001-of-00003.safetensors:  67% 1.23G/1.84G [00:06<00:02, 250MB/s]
# model-00001-of-00003.safetensors:  68% 1.25G/1.84G [00:07<00:02, 249MB/s]
# model-00001-of-00003.safetensors:  69% 1.28G/1.84G [00:07<00:02, 251MB/s]
# model-00001-of-00003.safetensors:  71% 1.31G/1.84G [00:07<00:02, 276MB/s]
# model-00001-of-00003.safetensors:  73% 1.34G/1.84G [00:07<00:01, 293MB/s]
# model-00001-of-00003.safetensors:  74% 1.37G/1.84G [00:07<00:01, 297MB/s]
# model-00001-of-00003.safetensors:  76% 1.40G/1.84G [00:07<00:01, 300MB/s]
# model-00001-of-00003.safetensors:  78% 1.43G/1.84G [00:07<00:01, 316MB/s]
# model-00001-of-00003.safetensors:  80% 1.47G/1.84G [00:07<00:01, 334MB/s]
# model-00001-of-00003.safetensors:  81% 1.50G/1.84G [00:07<00:01, 331MB/s]
# model-00001-of-00003.safetensors:  83% 1.53G/1.84G [00:07<00:00, 336MB/s]
# model-00001-of-00003.safetensors:  85% 1.56G/1.84G [00:08<00:00, 344MB/s]
# model-00001-of-00003.safetensors:  87% 1.60G/1.84G [00:08<00:00, 343MB/s]
# model-00001-of-00003.safetensors:  88% 1.63G/1.84G [00:08<00:00, 314MB/s]
# model-00001-of-00003.safetensors:  90% 1.66G/1.84G [00:08<00:00, 292MB/s]
# model-00001-of-00003.safetensors:  92% 1.68G/1.84G [00:08<00:00, 281MB/s]
# model-00001-of-00003.safetensors:  93% 1.71G/1.84G [00:08<00:00, 276MB/s]
# model-00001-of-00003.safetensors:  94% 1.74G/1.84G [00:08<00:00, 267MB/s]
# model-00001-of-00003.safetensors:  96% 1.76G/1.84G [00:08<00:00, 209MB/s]
# model-00001-of-00003.safetensors:  97% 1.79G/1.84G [00:09<00:00, 221MB/s]
# model-00001-of-00003.safetensors: 1.84GB [00:09, 215MB/s]
# ⬇️ Downloaded: model-00001-of-00003.safetensors
# Processing files:  56% 5/9 [00:11<00:15,  3.75s/file]
# model-00002-of-00003.safetensors:   0% 0.00/1.85G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0% 8.00k/1.85G [00:00<17:30:38, 31.5kB/s]
# model-00002-of-00003.safetensors:   2% 31.4M/1.85G [00:00<00:16, 117MB/s]
# model-00002-of-00003.safetensors:   4% 69.5M/1.85G [00:00<00:09, 212MB/s]
# model-00002-of-00003.safetensors:   5% 98.3M/1.85G [00:00<00:07, 241MB/s]
# model-00002-of-00003.safetensors:   7% 130M/1.85G [00:00<00:06, 269MB/s]
# model-00002-of-00003.safetensors:   9% 161M/1.85G [00:00<00:06, 288MB/s]
# model-00002-of-00003.safetensors:  10% 192M/1.85G [00:00<00:05, 300MB/s]
# model-00002-of-00003.safetensors:  12% 225M/1.85G [00:00<00:05, 312MB/s]
# model-00002-of-00003.safetensors:  14% 256M/1.85G [00:01<00:05, 305MB/s]
# model-00002-of-00003.safetensors:  15% 286M/1.85G [00:01<00:05, 304MB/s]
# model-00002-of-00003.safetensors:  17% 319M/1.85G [00:01<00:05, 319MB/s]
# model-00002-of-00003.safetensors:  19% 354M/1.85G [00:01<00:04, 331MB/s]
# model-00002-of-00003.safetensors:  20% 387M/1.85G [00:01<00:04, 336MB/s]
# model-00002-of-00003.safetensors:  22% 420M/1.85G [00:01<00:04, 341MB/s]
# model-00002-of-00003.safetensors:  24% 453M/1.85G [00:01<00:04, 341MB/s]
# model-00002-of-00003.safetensors:  26% 486M/1.85G [00:01<00:04, 297MB/s]
# model-00002-of-00003.safetensors:  27% 515M/1.85G [00:01<00:04, 300MB/s]
# model-00002-of-00003.safetensors:  29% 547M/1.85G [00:02<00:04, 310MB/s]
# model-00002-of-00003.safetensors:  31% 577M/1.85G [00:02<00:04, 311MB/s]
# model-00002-of-00003.safetensors:  32% 607M/1.85G [00:02<00:10, 134MB/s]
# model-00002-of-00003.safetensors:  33% 630M/1.85G [00:04<00:29, 44.1MB/s]
# model-00002-of-00003.safetensors:  35% 671M/1.85G [00:04<00:19, 67.1MB/s]
# model-00002-of-00003.safetensors:  38% 713M/1.85G [00:04<00:12, 96.0MB/s]
# model-00002-of-00003.safetensors:  39% 742M/1.85G [00:04<00:10, 115MB/s]
# model-00002-of-00003.safetensors:  41% 771M/1.85G [00:04<00:08, 139MB/s]
# model-00002-of-00003.safetensors:  42% 801M/1.85G [00:04<00:06, 165MB/s]
# model-00002-of-00003.safetensors:  44% 830M/1.85G [00:04<00:05, 188MB/s]
# model-00002-of-00003.safetensors:  45% 858M/1.85G [00:05<00:05, 210MB/s]
# model-00002-of-00003.safetensors:  47% 887M/1.85G [00:05<00:04, 231MB/s]
# model-00002-of-00003.safetensors:  48% 916M/1.85G [00:05<00:04, 246MB/s]
# model-00002-of-00003.safetensors:  50% 946M/1.85G [00:05<00:03, 264MB/s]
# model-00002-of-00003.safetensors:  52% 981M/1.85G [00:05<00:03, 291MB/s]
# model-00002-of-00003.safetensors:  53% 0.99G/1.85G [00:05<00:03, 300MB/s]
# model-00002-of-00003.safetensors:  55% 1.02G/1.85G [00:05<00:02, 307MB/s]
# model-00002-of-00003.safetensors:  57% 1.05G/1.85G [00:05<00:02, 316MB/s]
# model-00002-of-00003.safetensors:  59% 1.08G/1.85G [00:05<00:02, 319MB/s]
# model-00002-of-00003.safetensors:  60% 1.11G/1.85G [00:06<00:02, 312MB/s]
# model-00002-of-00003.safetensors:  62% 1.14G/1.85G [00:06<00:02, 289MB/s]
# model-00002-of-00003.safetensors:  63% 1.17G/1.85G [00:06<00:02, 279MB/s]
# model-00002-of-00003.safetensors:  65% 1.19G/1.85G [00:08<00:16, 42.5MB/s]
# model-00002-of-00003.safetensors:  66% 1.22G/1.85G [00:08<00:12, 54.6MB/s]
# model-00002-of-00003.safetensors:  68% 1.25G/1.85G [00:08<00:08, 73.5MB/s]
# model-00002-of-00003.safetensors:  69% 1.27G/1.85G [00:08<00:07, 87.8MB/s]
# model-00002-of-00003.safetensors:  70% 1.30G/1.85G [00:08<00:05, 113MB/s]
# model-00002-of-00003.safetensors:  72% 1.32G/1.85G [00:08<00:04, 131MB/s]
# model-00002-of-00003.safetensors:  73% 1.35G/1.85G [00:09<00:03, 159MB/s]
# model-00002-of-00003.safetensors:  75% 1.38G/1.85G [00:09<00:02, 191MB/s]
# model-00002-of-00003.safetensors:  76% 1.41G/1.85G [00:09<00:02, 219MB/s]
# model-00002-of-00003.safetensors:  78% 1.44G/1.85G [00:09<00:01, 244MB/s]
# model-00002-of-00003.safetensors:  80% 1.47G/1.85G [00:09<00:01, 259MB/s]
# model-00002-of-00003.safetensors:  81% 1.50G/1.85G [00:09<00:01, 270MB/s]
# model-00002-of-00003.safetensors:  83% 1.53G/1.85G [00:09<00:01, 289MB/s]
# model-00002-of-00003.safetensors:  84% 1.56G/1.85G [00:09<00:01, 286MB/s]
# model-00002-of-00003.safetensors:  86% 1.59G/1.85G [00:09<00:00, 296MB/s]
# model-00002-of-00003.safetensors:  88% 1.62G/1.85G [00:09<00:00, 307MB/s]
# model-00002-of-00003.safetensors:  89% 1.65G/1.85G [00:10<00:00, 311MB/s]
# model-00002-of-00003.safetensors:  91% 1.68G/1.85G [00:10<00:00, 315MB/s]
# model-00002-of-00003.safetensors:  92% 1.71G/1.85G [00:10<00:00, 302MB/s]
# model-00002-of-00003.safetensors:  94% 1.74G/1.85G [00:10<00:00, 279MB/s]
# model-00002-of-00003.safetensors:  95% 1.76G/1.85G [00:12<00:02, 41.8MB/s]
# model-00002-of-00003.safetensors:  97% 1.78G/1.85G [00:12<00:01, 49.7MB/s]
# model-00002-of-00003.safetensors:  98% 1.81G/1.85G [00:12<00:00, 68.6MB/s]
# model-00002-of-00003.safetensors: 1.85GB [00:12, 153MB/s]
# ⬇️ Downloaded: model-00002-of-00003.safetensors
# Processing files:  67% 6/9 [00:24<00:20,  6.97s/file]
# model-00003-of-00003.safetensors:   0% 0.00/1.35G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0% 8.00k/1.35G [00:00<13:24:37, 30.0kB/s]
# model-00003-of-00003.safetensors:   1% 16.1M/1.35G [00:00<00:24, 58.1MB/s]
# model-00003-of-00003.safetensors:   3% 44.9M/1.35G [00:00<00:10, 138MB/s]
# model-00003-of-00003.safetensors:   5% 70.2M/1.35G [00:00<00:07, 179MB/s]
# model-00003-of-00003.safetensors:   7% 100M/1.35G [00:00<00:06, 222MB/s]
# model-00003-of-00003.safetensors:   9% 127M/1.35G [00:00<00:05, 238MB/s]
# model-00003-of-00003.safetensors:  11% 153M/1.35G [00:00<00:05, 249MB/s]
# model-00003-of-00003.safetensors:  13% 182M/1.35G [00:00<00:04, 266MB/s]
# model-00003-of-00003.safetensors:  15% 214M/1.35G [00:01<00:04, 287MB/s]
# model-00003-of-00003.safetensors:  17% 242M/1.35G [00:01<00:04, 289MB/s]
# model-00003-of-00003.safetensors:  20% 273M/1.35G [00:01<00:03, 301MB/s]
# model-00003-of-00003.safetensors:  22% 303M/1.35G [00:01<00:04, 283MB/s]
# model-00003-of-00003.safetensors:  24% 332M/1.35G [00:01<00:03, 289MB/s]
# model-00003-of-00003.safetensors:  26% 364M/1.35G [00:01<00:03, 305MB/s]
# model-00003-of-00003.safetensors:  29% 396M/1.35G [00:01<00:03, 313MB/s]
# model-00003-of-00003.safetensors:  31% 426M/1.35G [00:01<00:03, 309MB/s]
# model-00003-of-00003.safetensors:  33% 456M/1.35G [00:01<00:03, 303MB/s]
# model-00003-of-00003.safetensors:  35% 487M/1.35G [00:02<00:03, 298MB/s]
# model-00003-of-00003.safetensors:  37% 515M/1.35G [00:02<00:03, 260MB/s]
# model-00003-of-00003.safetensors:  39% 541M/1.35G [00:02<00:03, 258MB/s]
# model-00003-of-00003.safetensors:  41% 573M/1.35G [00:02<00:03, 271MB/s]
# model-00003-of-00003.safetensors:  43% 600M/1.35G [00:02<00:03, 266MB/s]
# model-00003-of-00003.safetensors:  45% 628M/1.35G [00:02<00:02, 276MB/s]
# model-00003-of-00003.safetensors:  47% 655M/1.35G [00:02<00:02, 264MB/s]
# model-00003-of-00003.safetensors:  49% 680M/1.35G [00:02<00:03, 232MB/s]
# model-00003-of-00003.safetensors:  51% 706M/1.35G [00:02<00:02, 242MB/s]
# model-00003-of-00003.safetensors:  53% 733M/1.35G [00:03<00:02, 252MB/s]
# model-00003-of-00003.safetensors:  55% 759M/1.35G [00:03<00:02, 257MB/s]
# model-00003-of-00003.safetensors:  57% 788M/1.35G [00:03<00:02, 273MB/s]
# model-00003-of-00003.safetensors:  59% 815M/1.35G [00:03<00:02, 261MB/s]
# model-00003-of-00003.safetensors:  61% 841M/1.35G [00:03<00:02, 266MB/s]
# model-00003-of-00003.safetensors:  63% 867M/1.35G [00:03<00:02, 257MB/s]
# model-00003-of-00003.safetensors:  64% 892M/1.35G [00:03<00:02, 254MB/s]
# model-00003-of-00003.safetensors:  66% 917M/1.35G [00:03<00:01, 258MB/s]
# model-00003-of-00003.safetensors:  68% 942M/1.35G [00:03<00:01, 250MB/s]
# model-00003-of-00003.safetensors:  70% 967M/1.35G [00:04<00:01, 252MB/s]
# model-00003-of-00003.safetensors:  72% 991M/1.35G [00:04<00:01, 236MB/s]
# model-00003-of-00003.safetensors:  73% 0.99G/1.35G [00:04<00:01, 234MB/s]
# model-00003-of-00003.safetensors:  75% 1.02G/1.35G [00:04<00:01, 255MB/s]
# model-00003-of-00003.safetensors:  77% 1.04G/1.35G [00:04<00:01, 248MB/s]
# model-00003-of-00003.safetensors:  79% 1.07G/1.35G [00:04<00:01, 210MB/s]
# model-00003-of-00003.safetensors:  81% 1.09G/1.35G [00:04<00:01, 235MB/s]
# model-00003-of-00003.safetensors:  83% 1.12G/1.35G [00:04<00:00, 254MB/s]
# model-00003-of-00003.safetensors:  85% 1.15G/1.35G [00:04<00:00, 263MB/s]
# model-00003-of-00003.safetensors:  87% 1.18G/1.35G [00:05<00:00, 277MB/s]
# model-00003-of-00003.safetensors:  89% 1.21G/1.35G [00:05<00:00, 227MB/s]
# model-00003-of-00003.safetensors:  91% 1.23G/1.35G [00:05<00:00, 249MB/s]
# model-00003-of-00003.safetensors:  93% 1.26G/1.35G [00:05<00:00, 239MB/s]
# model-00003-of-00003.safetensors:  95% 1.28G/1.35G [00:05<00:00, 237MB/s]
# model-00003-of-00003.safetensors:  97% 1.31G/1.35G [00:05<00:00, 226MB/s]
# model-00003-of-00003.safetensors:  98% 1.33G/1.35G [00:05<00:00, 226MB/s]
# model-00003-of-00003.safetensors: 1.35GB [00:05, 247MB/s]
# ⬇️ Downloaded: model-00003-of-00003.safetensors
# Processing files:  78% 7/9 [00:31<00:13,  6.70s/file]
# model.safetensors.index.json:   0% 0.00/120k [00:00<?, ?B/s]
# model.safetensors.index.json: 128kB [00:00, 505kB/s]
# ⬇️ Downloaded: model.safetensors.index.json
# Processing files:  89% 8/9 [00:31<00:04,  4.75s/file]
# preprocessor_config.json:   0% 0.00/351 [00:00<?, ?B/s]
# preprocessor_config.json: 16.0kB [00:00, 52.6kB/s]
# ⬇️ Downloaded: preprocessor_config.json
# Processing files: 100% 9/9 [00:32<00:00,  3.57s/file]
# 🎙️ Initializing VibeVoice ...
# Loading processor & model from /content/VibeVoice/VibeVoice-1.5B
# tokenizer_config.json: 7.23kB [00:00, 23.7MB/s]
# vocab.json: 2.78MB [00:00, 124MB/s]
# merges.txt: 1.67MB [00:00, 134MB/s]
# tokenizer.json: 7.03MB [00:00, 176MB/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'Qwen2Tokenizer'.
# The class this function is called from is 'VibeVoiceTextTokenizerFast'.
# Loading checkpoint shards: 100% 3/3 [00:27<00:00,  9.03s/it]
# Language model attention: sdpa
# Found 9 voice files in /content/VibeVoice/demo/voices
# 🚀 Launching Gradio Demo...
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://65a86e43fb4d089ea2.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
